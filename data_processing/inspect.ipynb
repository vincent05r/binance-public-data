# %%
import pandas as pd
import numpy as np

# %%
data_path = "/home/vincent-4090/Documents/GitHub/binance-public-data/downloads/BTCUSDT_t2/BTCUSDT-1s-2025-10_to_2025-12-combined.csv"


df_data = pd.read_csv(data_path)

print(df_data[:5])
# Out:
#            Datetime       Open       High        Low      Close
# 0  1759276800000000  114048.94  114060.34  114048.93  114060.34
# 1  1759276801000000  114060.34  114072.01  114060.34  114072.01
# 2  1759276802000000  114072.00  114072.01  114063.58  114063.59
# 3  1759276803000000  114063.59  114063.59  114063.58  114063.59
# 4  1759276804000000  114063.59  114063.59  114063.58  114063.59
